# %% [markdown]
# # Pandas Introduction

# %% [markdown]
# In diesem Notebook wollen wir uns die Grundlagen Pandas und Jupyter anhang von Aufgaben genauer anschauen.

# %% [markdown]
# ### 1. Daten Laden und Sichten

# %% [markdown]
# - Laden Sie den Datensatz `hitters.csv` in einen Pandas DataFrame.

# %%
import pandas as pd
hitters = pd.read_csv("./hitters.csv")
hitters
# Out:
#                 Player  AtBat  Hits  HmRun  Runs  RBI  Walks  Years  CAtBat  \
# 0       -Andy Allanson    293    66      1    30   29     14      1     293
# 1          -Alan Ashby    315    81      7    24   38     39     14    3449
# 2         -Alvin Davis    479   130     18    66   72     76      3    1624
# 3        -Andre Dawson    496   141     20    65   78     37     11    5628
# 4    -Andres Galarraga    321    87     10    39   42     30      2     396
# ..                 ...    ...   ...    ...   ...  ...    ...    ...     ...
# 317      -Willie McGee    497   127      7    65   48     37      5    2703
# 318   -Willie Randolph    492   136      5    76   50     94     12    5511
# 319    -Wayne Tolleson    475   126      3    61   43     52      6    1700
# 320     -Willie Upshaw    573   144      9    85   60     78      8    3198
# 321     -Willie Wilson    631   170      9    77   44     31     11    4908
#
#      CHits  ...  CRuns  CRBI  CWalks  League Division PutOuts  Assists  \
# 0       66  ...     30    29      14       A        E     446       33
# 1      835  ...    321   414     375       N        W     632       43
# 2      457  ...    224   266     263       A        W     880       82
# 3     1575  ...    828   838     354       N        E     200       11
# 4      101  ...     48    46      33       N        E     805       40
# ..     ...  ...    ...   ...     ...     ...      ...     ...      ...
# 317    806  ...    379   311     138       N        E     325        9
# 318   1511  ...    897   451     875       A        E     313      381
# 319    433  ...    217    93     146       A        W      37      113
# 320    857  ...    470   420     332       A        E    1314      131
# 321   1457  ...    775   357     249       A        W     408        4
#
#      Errors  Salary  NewLeague
# 0        20     NaN          A
# 1        10   475.0          N
# 2        14   480.0          A
# 3         3   500.0          N
# 4         4    91.5          N
# ..      ...     ...        ...
# 317       3   700.0          N
# 318      20   875.0          A
# 319       7   385.0          A
# 320      12   960.0          A
# 321       3  1000.0          A
#
# [322 rows x 21 columns]

# %% [markdown]
# - Schauen Sie sich die ersten 5 Zeilen dieses DataFrame an und lesen Sie sich kurz die Beschreibung zu den Daten durch, diese finden Sie [hier](https://rdrr.io/cran/ISLR/man/Hitters.html).

# %%
hitters.head()
# Out:
#               Player  AtBat  Hits  HmRun  Runs  RBI  Walks  Years  CAtBat  \
# 0     -Andy Allanson    293    66      1    30   29     14      1     293
# 1        -Alan Ashby    315    81      7    24   38     39     14    3449
# 2       -Alvin Davis    479   130     18    66   72     76      3    1624
# 3      -Andre Dawson    496   141     20    65   78     37     11    5628
# 4  -Andres Galarraga    321    87     10    39   42     30      2     396
#
#    CHits  ...  CRuns  CRBI  CWalks  League Division PutOuts  Assists  Errors  \
# 0     66  ...     30    29      14       A        E     446       33      20
# 1    835  ...    321   414     375       N        W     632       43      10
# 2    457  ...    224   266     263       A        W     880       82      14
# 3   1575  ...    828   838     354       N        E     200       11       3
# 4    101  ...     48    46      33       N        E     805       40       4
#
#    Salary  NewLeague
# 0     NaN          A
# 1   475.0          N
# 2   480.0          A
# 3   500.0          N
# 4    91.5          N
#
# [5 rows x 21 columns]

# %% [markdown]
# - Geben Sie die Datentypen aller Spalten aus

# %%
hitters.dtypes
# Out:
# Player        object
# AtBat          int64
# Hits           int64
# HmRun          int64
# Runs           int64
# RBI            int64
# Walks          int64
# Years          int64
# CAtBat         int64
# CHits          int64
# CHmRun         int64
# CRuns          int64
# CRBI           int64
# CWalks         int64
# League        object
# Division      object
# PutOuts        int64
# Assists        int64
# Errors         int64
# Salary       float64
# NewLeague     object
# dtype: object

# %% [markdown]
# - Geben Sie das Maximum und Minimum der Spalte `Hits` aus.

# %%
max = hitters["Hits"].max()
min = hitters["Hits"].min()
print("Max: " + str(max))
print("Min: " + str(min))
# Out:
# Max: 238
# Min: 1

# %% [markdown]
# - Geben Sie das 25%, 50% und 75% Quantil für die Spalte `Salary` aus.

# %%
salary_desc = hitters["Salary"].describe()
print("25%: " + str(salary_desc[4]))
print("50%: " + str(salary_desc[5]))
print("75%: " + str(salary_desc[6]))
# Out:
# 25%: 190.0
# 50%: 425.0
# 75%: 750.0

# %% [markdown]
# ### 2. Selektion von Daten

# %% [markdown]
# - Erstellen Sie einen DataFrame der nur die Spalten `AtBat` und `Hits` enthält.

# %%
hitters_short = hitters[["AtBat", "Hits"]]
hitters_short
# Out:
#      AtBat  Hits
# 0      293    66
# 1      315    81
# 2      479   130
# 3      496   141
# 4      321    87
# ..     ...   ...
# 317    497   127
# 318    492   136
# 319    475   126
# 320    573   144
# 321    631   170
#
# [322 rows x 2 columns]

# %% [markdown]
# - Erstellen Sie einen DataFrame in dem Spieler sind welche mehr als 100 `Hits` haben. Geben Sie aus wie viele Spieler dies erfüllen.

# %%
hitters_tiny = hitters_short[hitters_short["Hits"] > 100]
hitters_tiny
#155 Spieler
# Out:
#      AtBat  Hits
# 2      479   130
# 3      496   141
# 5      594   169
# 10     574   159
# 12     418   113
# ..     ...   ...
# 317    497   127
# 318    492   136
# 319    475   126
# 320    573   144
# 321    631   170
#
# [155 rows x 2 columns]

# %% [markdown]
# - Geben Sie einen DataFrame aus, in dem nur Spieler mit mehr als 100 `Hits` und weniger als 500 `AtBat` haben.

# %%
hitters_micro = hitters_short[(hitters_short["Hits"] > 100) & (hitters_short["AtBat"] < 500)]
hitters_micro
# Out:
#      AtBat  Hits
# 2      479   130
# 3      496   141
# 12     418   113
# 18     407   104
# 21     426   109
# ..     ...   ...
# 312    387   124
# 314    408   117
# 317    497   127
# 318    492   136
# 319    475   126
#
# [66 rows x 2 columns]

# %% [markdown]
# - Geben Sie den Namen und Gehalt der Spieler aus welche länger als 10 Jahre in der MLB gespielt haben.

# %%
players_long = hitters[ hitters["Years"]>10 ][ ["Player", "Salary", "Years"] ]
players_long
# Out:
#                Player  Salary  Years
# 1         -Alan Ashby   475.0     14
# 3       -Andre Dawson   500.0     11
# 5    -Alfredo Griffin   750.0     11
# 9     -Andre Thornton  1100.0     13
# 14        -Bill Almon   240.0     13
# ..                ...     ...    ...
# 299     -Tom Paciorek   235.0     17
# 302       -Tony Perez     NaN     23
# 306      -Ted Simmons   500.0     19
# 318  -Willie Randolph   875.0     12
# 321    -Willie Wilson  1000.0     11
#
# [84 rows x 3 columns]

# %% [markdown]
# ### 3. Plotting von Daten

# %% [markdown]
# - Erstellen Sie einen einfachen Plot für die `Salary` Spalte.

# %%
hitters["Salary"].plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# - Zeichnen Sie einen Scatter-Plot, um das Verhältnis zwischen `Salary` und `HmRun` zu untersuchen.

# %%
hitters.plot.scatter(x="Salary", y="HmRun", alpha=0.7)
# Out:
# <AxesSubplot:xlabel='Salary', ylabel='HmRun'>

# %% [markdown]
# ### 4. Neue Spalten

# %% [markdown]
# - Erstellen Sie eine neue Spalte `avg_hits` welche die durchschnittle Anzahl an `Hits` pro gespieltem Jahr widergibt.

# %%
hitters["avg_hits"] = hitters["Hits"] / hitters["Years"]
hitters
# Out:
#                 Player  AtBat  Hits  HmRun  Runs  RBI  Walks  Years  CAtBat  \
# 0       -Andy Allanson    293    66      1    30   29     14      1     293
# 1          -Alan Ashby    315    81      7    24   38     39     14    3449
# 2         -Alvin Davis    479   130     18    66   72     76      3    1624
# 3        -Andre Dawson    496   141     20    65   78     37     11    5628
# 4    -Andres Galarraga    321    87     10    39   42     30      2     396
# ..                 ...    ...   ...    ...   ...  ...    ...    ...     ...
# 317      -Willie McGee    497   127      7    65   48     37      5    2703
# 318   -Willie Randolph    492   136      5    76   50     94     12    5511
# 319    -Wayne Tolleson    475   126      3    61   43     52      6    1700
# 320     -Willie Upshaw    573   144      9    85   60     78      8    3198
# 321     -Willie Wilson    631   170      9    77   44     31     11    4908
#
#      CHits  ...  CRBI  CWalks  League  Division PutOuts Assists  Errors  \
# 0       66  ...    29      14       A         E     446      33      20
# 1      835  ...   414     375       N         W     632      43      10
# 2      457  ...   266     263       A         W     880      82      14
# 3     1575  ...   838     354       N         E     200      11       3
# 4      101  ...    46      33       N         E     805      40       4
# ..     ...  ...   ...     ...     ...       ...     ...     ...     ...
# 317    806  ...   311     138       N         E     325       9       3
# 318   1511  ...   451     875       A         E     313     381      20
# 319    433  ...    93     146       A         W      37     113       7
# 320    857  ...   420     332       A         E    1314     131      12
# 321   1457  ...   357     249       A         W     408       4       3
#
#      Salary  NewLeague   avg_hits
# 0       NaN          A  66.000000
# 1     475.0          N   5.785714
# 2     480.0          A  43.333333
# 3     500.0          N  12.818182
# 4      91.5          N  43.500000
# ..      ...        ...        ...
# 317   700.0          N  25.400000
# 318   875.0          A  11.333333
# 319   385.0          A  21.000000
# 320   960.0          A  18.000000
# 321  1000.0          A  15.454545
#
# [322 rows x 22 columns]

# %% [markdown]
# ### 5. Summary Statistics

# %% [markdown]
# - Geben Sie an welche unterschiedlichen Werte in der `Years`-Spalte vorkommen und wie oft diese vorkommen.

# %%
hitters[["Years", "Player"]].groupby("Years").count()
# Out:
#        Player
# Years
# 1          22
# 2          25
# 3          29
# 4          36
# 5          30
# 6          30
# 7          21
# 8          16
# 9          15
# 10         14
# 11         10
# 12         14
# 13         12
# 14         13
# 15          9
# 16          7
# 17          7
# 18          7
# 19          1
# 20          2
# 23          1
# 24          1

# %% [markdown]
# - Geben Sie das durchschnittliche Gehalt aller Spieler per `Division` an.

# %%
hitters[["Division", "Salary"]].groupby("Division").mean()
# Out:
#               Salary
# Division
# E         624.271364
# W         450.876873
